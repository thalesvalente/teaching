# %% [markdown]
# <a href="https://colab.research.google.com/github/thalesvalente/teaching/blob/main/data-mining-applied-to-engineering/1-lessons/material-pre-processamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula Prática de Análise de Dados

# %% [markdown]
# # Sumário
#
# Esta aula é uma introdução prática ao uso das bibliotecas Pandas, Matplotlib e Seaborn para análise de dados em Python.

# %% [markdown]
# ## Módulo 1: Pandas para Análise de Dados

# %% [markdown]
# ### Tópico 1.1: Introdução ao Pandas

# %% [markdown]
# - Configuração e conceitos fundamentais
# - Estruturas de dados do Pandas: Series e DataFrames
# - Carregamento de dados de diferentes fontes (CSV, Excel, bancos de dados)

# %% [markdown]
# ### Tópico 1.2: Manipulação Básica de Dados

# %% [markdown]
# - Escrever dados em diferentes formatos
# - Inspeção inicial dos dados e funções úteis
# - Indexação, filtragem e subconjuntos de dados

# %% [markdown]
# ### Tópico 1.3: Limpeza e Preparação de Dado

# %% [markdown]
# - Verificação de dados faltantes
# - Imputação/Preenchimento de dados
# - Limpeza de dados por exclusão

# %% [markdown]
# ### Tópico 1.4: Operações com DataFrames

# %% [markdown]
# - Operações estatísticas básicas
# - Agrupamento e agregação com groupby
# - Merge, join e concatenação

# %% [markdown]
# ### Tópico 1.5: Transformação de Dados

# %% [markdown]
# - Transformação e normalização de dados
# - Funções de mapeamento: apply, map e applymap
# - Reshaping e pivotamento

# %% [markdown]
# ### Tópico 1.5: Pandas Avançado

# %% [markdown]
# - Trabalhando com dados de texto e datas
# - Criação e manipulação de índices multi-nível
# - Técnicas de slicing e dicing avançadas
# - Trabalhando com séries temporais e dados categóricos

# %% [markdown]
# ## Módulo 2: Visualização de Dados com Matplotlib

# %% [markdown]
# ### Tópico 2.1: Fundamentos de Plotagem com Matplotlib

# %% [markdown]
# - Estrutura de uma figura no Matplotlib
# - Criando gráficos básicos: linhas, barras, histogramas

# %% [markdown]
# ### Tópico 2.2: Estilização de Gráfico

# %% [markdown]
# - Customização de cores, linhas e marcadores
# - Eixos, títulos, legendas e anotações

# %% [markdown]
# ### Tópico 2.3: Gráficos Avançados

# %% [markdown]
# - Combinando múltiplos gráficos em uma figura
# - Explorando subplots e figuras complexas
# - Gráficos de barra empilhados e agrupados
# - Visualizações de séries temporais

# %% [markdown]
# ### Tópico 2.4: Gráficos Interativos e Animações

# %% [markdown]
# - Criando visualizações interativas
# - Introdução a animações com Matplotlib

# %% [markdown]
# ## Módulo 3: Exploração de Dados com Seaborn

# %% [markdown]
# ### Tópico 3.1: Introdução ao Seaborn

# %% [markdown]
# - Diferenças entre Seaborn e Matplotlib
# - Estilos e temas em Seaborn

# %% [markdown]
# ### Tópico 3.2: Visualizações Estatísticas

# %% [markdown]
# - Plotagens de distribuição e densidade: distplot, kdeplot, rugplot
# - Histogramas e KDEs com Seaborn
# - Visualizações de categorias: de caixa, violino e swarm (boxplot, violinplot, stripplot)

# %% [markdown]
# ### Tópico 3.4: Visualizações Multivariados

# %% [markdown]
# - Visualizações de pares e matrizes de correlação
# - Heatmaps para visualização de matrizes de correlação
# - Explorando interações entre múltiplas variáveis

# %% [markdown]
# ### Tópico 3.5: Visualizações Avançadas

# %% [markdown]
# - Regressões lineares com Seaborn (regplot e lmplot)
# - Gráficos de contagem e categorias avançadas (factorplot e swarmplot)

# %% [markdown]
# ### Tópico 3.6: Customização de Visualizações com Seaborn

# %% [markdown]
# - Personalização avançada de gráficos
# - Combinação de múltiplos tipos de gráficos para visualizações complexas

# %% [markdown]
# # Módulo 1: Pandas para Análise de Dados

# %% [markdown]
# ## Tópico 1.1: Introdução ao Pandas

# %% [markdown]
# ### 1.1.1 Configuração e conceitos fundamentais

# %% [markdown]
# Pandas é uma biblioteca poderosa do Python que fornece estruturas de dados e ferramentas de análise de dados fáceis de usar e de alta performance. É fundamental no dia-a-dia de um cientista de dados para manipular e preparar dados para análise.
#
# Nesta aula, vamos aprender como instalar o Pandas, entender suas principais estruturas de dados e começar a explorar um conjunto de dados.

# %% [markdown]
# #### - Instalação do Pandas

# %% [markdown]
# Para instalar o Pandas, execute a cécula abaixo:

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\selah\anaconda3\envs\moda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\selah\anaconda3\envs\moda\lib\site-packages)

# %% [markdown]
# #### - Importando o Pandas

# %% [markdown]
# Após a instalação, podemos importar o Pandas para o nosso ambiente de trabalho. A convenção é importá-lo com o alias pd:

# %%
import pandas as pd

# %% [markdown]
# #### - Carregando o Conjunto de Dados Iris

# %% [markdown]
# O conjunto de dados Iris é um dos conjuntos mais famosos na literatura de reconhecimento de padrões e em aprendizado de máquina. Ele contém as medições das sépalas e pétalas de 150 flores de íris de três espécies diferentes.
#
# Para fins didáticos, o conjunto de dados Iris está disponível diretamente através do repositório UCI Machine Learning ou de outras fontes na internet. Vamos carregá-lo utilizando o Pandas:

# %%
# Carregar o conjunto de dados Iris de uma URL pública diretamente para um DataFrame do Pandas
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris = pd.read_csv(url, header=None, names=col_names)

# %% [markdown]
# #### - Explorando o Conjunto de Dados

# %% [markdown]
# Agora que carregamos os dados, vamos explorar o que temos no DataFrame:

# %%
# Visualizar as primeiras 5 linhas do DataFrame
iris.head()

# %%
# Visualizar as últimas 5 linhas do DataFrame
iris.tail()

# %%
# Verificar a quantidade de linhas e colunas no DataFrame
iris.shape

# %%
# O Pandas oferece métodos convenientes para uma descrição estatística rápida dos dados, como o método .describe():
# Obter uma descrição estatística do conjunto de dados
iris.describe()

# %%
# Verificando Tipos de Dados e Dados Ausentes
# É crucial conhecer os tipos de dados em cada coluna e verificar a existência de valores ausentes:
# Verificar os tipos de dados das colunas
iris.dtypes

# %%
# Verificar se há valores ausentes no DataFrame
iris.isnull().sum()

# %% [markdown]
# Ao final desta aula prática, os alunos terão uma compreensão básica de como começar a usar o Pandas para carregar e inspecionar um conjunto de dados.
#
# No próximo tópico, aprofundaremos em manipulações de DataFrames, incluindo filtragem de dados, limpeza e transformações mais complexas.

# %% [markdown]
# ### 1.1.2 Estruturas de dados do Pandas: Series e DataFrames

# %% [markdown]
# O Pandas fornece duas estruturas de dados principais: `Series` e `DataFrames`. Estas estruturas são construídas em cima do `NumPy`, o que significa que elas são rápidas.

# %% [markdown]
# #### - Series

# %% [markdown]
# Uma `Series` é como um array unidimensional, uma lista de valores. Cada valor tem um índice, e os índices são, por padrão, os números de 0 a n - 1, onde `n` é o número de valores na `Series`.

# %%
# Criando uma Series de um array NumPy
import numpy as np
import pandas as pd

data = np.array(['a', 'b', 'c', 'd'])
s = pd.Series(data)
print(s)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %% [markdown]
# Você pode personalizar o índice dos valores ao criar a Series:

# %%
# Criando uma Series com um índice definido
s = pd.Series(data, index=[100, 101, 102, 103])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# dtype: object

# %% [markdown]
# #### - Dataframe

# %% [markdown]
# Um DataFrame é uma estrutura de dados bidimensional com colunas que podem ter tipos diferentes. Você pode pensar em um DataFrame como uma planilha do Excel ou uma tabela SQL.

# %%
# Criando um DataFrame a partir de um dicionário de arrays NumPy
data = {
    'Species': ['Setosa', 'Versicolor', 'Virginica'],
    'Length': [5.1, 6.9, 5.6],
    'Width': [3.5, 3.2, 2.8]
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Species  Length  Width
# 0      Setosa     5.1    3.5
# 1  Versicolor     6.9    3.2
# 2   Virginica     5.6    2.8

# %% [markdown]
# Outra forma de visualizar é usando o comando display. Dessa forma, você visualiza o dataframe mais próximo de uma tabela

# %%
display(df)
# Out:
#       Species  Length  Width
# 0      Setosa     5.1    3.5
# 1  Versicolor     6.9    3.2
# 2   Virginica     5.6    2.8

# %% [markdown]
# #### - Criação de DataFrame a partir de uma Series

# %% [markdown]
# Um DataFrame também pode ser criado a partir de uma Series do Pandas:

# %%
# Criando uma Series com dados complexos
import pandas as pd

data = pd.Series({
    'a': ['Setosa', 5.1, 3.5],
    'b': ['Versicolor', 6.9, 3.2],
    'c': ['Virginica', 5.6, 2.8]
})

# Criando um DataFrame a partir de uma Series de listas
df = pd.DataFrame(data.tolist(), columns=['Species', 'Length', 'Width'])
print(df)
# Out:
#       Species  Length  Width
# 0      Setosa     5.1    3.5
# 1  Versicolor     6.9    3.2
# 2   Virginica     5.6    2.8

# %% [markdown]
# Este código primeiro cria uma Series onde cada chave no dicionário corresponde a uma lista de valores relacionados a espécies de íris e suas medidas. Em seguida, ele converte esta Series em um DataFrame, explicitamente convertendo a Series em uma lista de listas (usando .tolist()) e especificando os nomes das colunas.
#
# Aqui está o que o código faz:
#
# - `data.tolist()` converte a Series em uma lista de listas.
# - `pd.DataFrame(...)` cria um DataFrame usando a lista de listas como dados e especifica os nomes das colunas com columns=[...].
# Perceba que dessa forma, os índices dos dados das séries sumiram. No entanto, há formas de contornar isso

# %% [markdown]
# Na transformação para DataFrame, os índices da Series (neste caso `a`, `b`, `c`) não são automaticamente transferidos para o DataFrame como rótulos de linha, a menos que especificamente os mantenhamos.
#
# Para incluir esses índices como uma coluna no DataFrame ou para usá-los como índices no DataFrame final, precisamos de uma etapa adicional.

# %%
import pandas as pd

# Dados originais com índices 'a', 'b', 'c'
data = pd.Series({
    'a': ['Setosa', 5.1, 3.5],
    'b': ['Versicolor', 6.9, 3.2],
    'c': ['Virginica', 5.6, 2.8]
})

# Criando um DataFrame usando os índices da Series como índices do DataFrame
df = pd.DataFrame(data.tolist(), columns=['Species', 'Length', 'Width'], index=data.index)
print(df)
# Out:
#       Species  Length  Width
# a      Setosa     5.1    3.5
# b  Versicolor     6.9    3.2
# c   Virginica     5.6    2.8

# %% [markdown]
# #### - Acessando Dados no DataFrame

# %% [markdown]
# ##### Acesso básico

# %% [markdown]
# Você pode acessar dados em um DataFrame de várias maneiras. Por exemplo:

# %%
# Acessando uma coluna específica
display(df['Length'])
# Out:
# a    5.1
# b    6.9
# c    5.6
# Name: Length, dtype: float64

# %%
# Acessando uma linha específica pelo índice
print(df.iloc[1])
# Out:
# Species    Versicolor
# Length            6.9
# Width             3.2
# Name: b, dtype: object

# %%
### Acessando um valor específico
print(df.iloc[1, 1])
# Out:
# 6.9

# %%
### Acessando um valor específico usando o nome da coluna e do índice
print(df.at['b', 'Length'])
# Out:
# 6.9

# %% [markdown]
# Você pode usar o método `iloc` para acessar valores pelo índice numérico (baseado na posição) ou `loc` para acessar valores usando o índice baseado em etiquetas (label). Para acessar usando o nome da coluna juntamente com o número da linha, a abordagem mais comum e recomendada é `iloc`, que é puramente baseada na posição numérica.

# %% [markdown]
# ##### Uso avançado do iloc e get_loc

# %% [markdown]
# O `iloc` é usado para selecionar dados baseando-se na posição numérica das linhas e colunas. A sintaxe é `dataframe.iloc[linha, coluna]`, onde linha e coluna são as posições numéricas (iniciando de 0). O `get_loc` é para encontrar a posição da coluna pelo nome.

# %%
# Acessando o valor da coluna 'Length' na segunda linha
# Lembrando que a contagem começa do zero, então a segunda linha é indexada por 1
valor_especifico = df.iloc[1, df.columns.get_loc('Length')]  # Usando iloc e get_loc para encontrar a posição da coluna pelo nome
print('O valor acessado é:', valor_especifico)
# Out:
# O valor acessado é: 6.9

# %% [markdown]
# ##### Uso de loc

# %% [markdown]
# O `loc`, em contraste, é usado para acessar elementos com base no nome do índice e no nome da coluna. A sintaxe é `dataframe.loc[indice, 'nome_da_coluna']`. Tem o mesmo efeito do `at`.

# %%
# Continuando com o DataFrame anterior:
# Acessando o valor da coluna 'Length' na segunda linha usando loc
# Supondo que o índice seja padrão (0, 1, 2, ...)
valor_especifico_loc = df.loc['a', 'Length']  # Usando loc com o índice numérico e o nome da coluna diretamente
print('O valor acessado é:', valor_especifico_loc)

valor_especifico_loc = df.at['a', 'Length']  # Usando at com o índice numérico e o nome da coluna diretamente
print('O valor acessado é:', valor_especifico_loc)
# Out:
# O valor acessado é: 5.1
# O valor acessado é: 5.1

# %% [markdown]
# ##### Quando Usar iloc vs loc
# - Use `iloc` quando você precisa de acesso baseado na posição numérica das linhas/colunas.
# - Use `loc` quando você está lidando com índices personalizados ou precisa acessar as linhas/colunas pelos seus nomes ou etiquetas.

# %% [markdown]
# #### - Resumo
# Series e DataFrames são os blocos de construção do Pandas. Com eles, você pode armazenar e manipular dados de maneira eficiente e intuitiva. Ao dominar essas estruturas, você terá uma base sólida para realizar análises de dados complexas e poderosas com o Pandas.
#
# No próximo tópico, vamos mergulhar mais fundo em como manipular DataFrames, incluindo seleção, filtragem e limpeza de dados.

# %% [markdown]
# ### 1.2.3 Carregamento de dados de diferentes fontes (CSV, Excel, bancos de dados)

# %% [markdown]
# #### - Carregando Dados de Arquivos CSV

# %% [markdown]
# - Pandas é uma ferramenta extremamente eficaz para ler dados de uma variedade de fontes como CSV, Excel e bancos de dados SQL. Neste tópico, vamos aprender como carregar dados de cada uma dessas fontes.
# - Arquivos CSV (Comma-Separated Values) são uma das formas mais comuns e simples de troca de dados. Pandas facilita a leitura desses arquivos com a função `read_csv`.

# %%
# Exemplo de como carregar um arquivo CSV
import pandas as pd

# Substitua 'caminho_para_o_arquivo.csv' pelo caminho do seu arquivo
df_csv = pd.read_csv('caminho_para_o_arquivo.csv')
print(df_csv.head())

# %% [markdown]
# #### - Carregando Dados de Arquivos Excel

# %% [markdown]
# Você precisa ter a biblioteca `openpyxl` ou `xlrd` instalada para ler arquivos Excel. Você pode instalar qualquer uma delas usando pip:

# %%
# openpyxl é para o formato .xlsx
#%pip install openpyxl
# xlrd é para o formato .xls
#%pip install xlrd
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/96.5 kB ? eta -:--:--
#    ------------ --------------------------- 30.7/96.5 kB 1.4 MB/s eta 0:00:01
#    ------------ --------------------------- 30.7/96.5 kB 1.4 MB/s eta 0:00:01
#    ------------------------- -------------- 61.4/96.5 kB 550.5 kB/s eta 0:00:01
#    ---------------------------------------- 96.5/96.5 kB 690.3 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\selah\anaconda3\envs\moda\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\selah\anaconda3\envs\moda\lib\site-packages)

# %% [markdown]
# ##### Leitura Local

# %% [markdown]
# Pandas pode ler esses arquivos usando a função `read_excel`.

# %%
# Exemplo de como carregar um arquivo Excel
# Substitua 'caminho_para_o_arquivo.xlsx' pelo caminho do seu arquivo
df_excel = pd.read_excel('caminho_para_o_arquivo.xlsx')
print(df_excel.head())

# %% [markdown]
# ##### Leitura direto de link on-line

# %% [markdown]
# Algumas vezes você pode querer fazer download diretamente da internet. Para fazer download e ler o excel usando código, faça o seguinte:

# %%
import pandas as pd
import io
import requests

# Use the direct raw link to the Excel file
url_excel = "https://raw.githubusercontent.com/bharathirajatut/sample-excel-dataset/master/airline.xls"
response = requests.get(url_excel)

if response.status_code == 200:
    data_excel = io.BytesIO(response.content)
    # Ensure you use the correct engine; 'openpyxl' is for .xlsx, use 'xlrd' for .xls files
    df_excel = pd.read_excel(data_excel, engine='xlrd')
    display(df_excel.head())
else:
    print("Falha ao baixar o arquivo. Status Code:", response.status_code)
# Out:
#    YEAR      Y      W       R      L      K
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %% [markdown]
# ##### Leitura direto de link on-line com descompactação automática

# %% [markdown]
# Algumas vezes você pode querer fazer download diretamente da internet, mas o arquivo pode estar zipado. Para fazer download, descompactar e ler o excel usando código, faça o seguinte:

# %%
import requests
from zipfile import ZipFile
import io
import pandas as pd

# URL do arquivo ZIP
url_zip = 'https://www.thespreadsheetguru.com/wp-content/uploads/2022/12/EmployeeSampleData.zip'

# Fazendo o download do arquivo ZIP
response = requests.get(url_zip)
if response.status_code == 200:
    zip_file = io.BytesIO(response.content)
    
    # Abrindo o arquivo ZIP
    with ZipFile(zip_file, 'r') as z:
        # Lista todos os arquivos contidos no arquivo ZIP
        print(z.namelist())
        
        # Supondo que você saiba o nome do arquivo Excel ou é o único arquivo
        # Extrai o arquivo Excel
        for file_name in z.namelist():
            if file_name.endswith('.xlsx'):
                z.extract(file_name, 'path_to_extract')
                # Carregando o arquivo Excel com Pandas
                df = pd.read_excel('path_to_extract/' + file_name)
                display(df.head())

else:
    print(f"Erro ao baixar o arquivo: {response.status_code}")
# Out:
# ['Employee Sample Data.csv', 'Employee Sample Data.xlsx']
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# ...

# %% [markdown]
# #### - Carregando Dados de Bancos de Dados SQL

# %% [markdown]
# Pandas também pode ser usado para ler dados diretamente de bancos de dados SQL. Você precisará de uma biblioteca adicional para fazer a conexão com o banco de dados específico que você está usando (por exemplo, PyMySQL para MySQL, psycopg2 para PostgreSQL).

# %%
#%pip install sqlalchemy

# %%
# Exemplo de como carregar dados de um banco de dados SQL usando SQLAlchemy
from sqlalchemy import create_engine

# Substitua 'tipo_de_banco://usuario:senha@host:porta/nome_do_banco' pela sua string de conexão
engine = create_engine('tipo_de_banco://usuario:senha@host:porta/nome_do_banco')
df_sql = pd.read_sql('SELECT * FROM nome_da_tabela', con=engine)
print(df_sql.head())

# %% [markdown]
# No entanto, não iremos explorar banco de dados nessa disciplina

# %% [markdown]
# ## Tópico 1.2: Manipulação Básica de Dados

# %% [markdown]
# ### 1.2.1 Escrever dados em diferentes formatos

# %% [markdown]
# Primeiro, vamos carregar um dataframe da internet

# %%
import requests
from zipfile import ZipFile
import io
import pandas as pd

# URL do arquivo ZIP
url_zip = 'https://www.thespreadsheetguru.com/wp-content/uploads/2022/12/EmployeeSampleData.zip'

# Fazendo o download do arquivo ZIP
response = requests.get(url_zip)
if response.status_code == 200:
    zip_file = io.BytesIO(response.content)
    
    # Abrindo o arquivo ZIP
    with ZipFile(zip_file, 'r') as z:
        # Lista todos os arquivos contidos no arquivo ZIP
        print(z.namelist())
        
        # Supondo que você saiba o nome do arquivo Excel ou é o único arquivo
        # Extrai o arquivo Excel
        for file_name in z.namelist():
            if file_name.endswith('.xlsx'):
                z.extract(file_name, 'path_to_extract')
                # Carregando o arquivo Excel com Pandas
                df = pd.read_excel('path_to_extract/' + file_name)
                display(df.head())

else:
    print(f"Erro ao baixar o arquivo: {response.status_code}")
# Out:
# ['Employee Sample Data.csv', 'Employee Sample Data.xlsx']
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55 2016-04-08         141604
# 1           Manufacturing    Male      Asian   59 1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50 2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26 2019-09-27          84913
# 4           Manufacturing    Male      Asian   55 1995-11-20          95409
#
#    Bonus %        Country       City  Exit Date
# ...

# %% [markdown]
# #### - Escrever em Arquivos CSV

# %%
import pandas as pd

# Suponha que df seja o DataFrame que você deseja escrever em CSV
df.to_csv('meu_novo_arquivo.csv', index=False)
df2 = pd.read_csv('meu_novo_arquivo.csv')
display(df2.head())
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55  2016-04-08         141604
# 1           Manufacturing    Male      Asian   59  1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50  2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26  2019-09-27          84913
# 4           Manufacturing    Male      Asian   55  1995-11-20          95409
#
#    Bonus %        Country       City   Exit Date
# 0     0.15  United States    Seattle  2021-10-16
# ...

# %% [markdown]
# #### - Escrever em Arquivos Excel

# %%
df2.to_excel('nome_do_arquivo.xlsx', sheet_name='Sheet1', index=False)
df3 = pd.read_excel('nome_do_arquivo.xlsx')
display(df3.head())
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55  2016-04-08         141604
# 1           Manufacturing    Male      Asian   59  1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50  2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26  2019-09-27          84913
# 4           Manufacturing    Male      Asian   55  1995-11-20          95409
#
#    Bonus %        Country       City   Exit Date
# 0     0.15  United States    Seattle  2021-10-16
# ...

# %% [markdown]
# #### - Escrever em Arquivos JSON

# %%
df.to_json('nome_do_arquivo.json', orient='records')
df4 = pd.read_json('nome_do_arquivo.json')
display(df4.head())
# Out:
#      EEID        Full Name                 Job Title Department  \
# 0  E02387      Emily Davis                Sr. Manger         IT
# 1  E04105    Theodore Dinh       Technical Architect         IT
# 2  E02572     Luna Sanders                  Director    Finance
# 3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age      Hire Date  \
# 0  Research & Development  Female      Black   55  1460073600000
# 1           Manufacturing    Male      Asian   59   880761600000
# 2     Speciality Products  Female  Caucasian   50  1161820800000
# 3           Manufacturing  Female  Caucasian   26  1569542400000
# 4           Manufacturing    Male      Asian   55   816825600000
#
#    Annual Salary  Bonus %        Country       City     Exit Date
# 0         141604     0.15  United States    Seattle  1.634342e+12
# ...

# %% [markdown]
# #### - Escrever em Arquivos HTML

# %%
df.to_html('nome_do_arquivo.html')
df5 = pd.read_html('nome_do_arquivo.html')[0]
display(df5.head())
# Out:
#    Unnamed: 0    EEID        Full Name                 Job Title Department  \
# 0           0  E02387      Emily Davis                Sr. Manger         IT
# 1           1  E04105    Theodore Dinh       Technical Architect         IT
# 2           2  E02572     Luna Sanders                  Director    Finance
# 3           3  E02832  Penelope Jordan  Computer Systems Manager         IT
# 4           4  E01639        Austin Vo               Sr. Analyst    Finance
#
#             Business Unit  Gender  Ethnicity  Age   Hire Date  Annual Salary  \
# 0  Research & Development  Female      Black   55  2016-04-08         141604
# 1           Manufacturing    Male      Asian   59  1997-11-29          99975
# 2     Speciality Products  Female  Caucasian   50  2006-10-26         163099
# 3           Manufacturing  Female  Caucasian   26  2019-09-27          84913
# 4           Manufacturing    Male      Asian   55  1995-11-20          95409
#
# ...

# %% [markdown]
# ### 1.2.2 Inspeção inicial dos dados e funções úteis

# %% [markdown]
# Para uma inspeção inicial de dados e utilização de funções úteis no Pandas, é essencial conhecer as ferramentas disponíveis que permitem explorar e entender rapidamente seus datasets. Aqui está um guia prático que aborda como realizar uma análise exploratória inicial de dados usando Pandas, uma biblioteca extremamente poderosa e flexível para manipulação de dados em Python.

# %% [markdown]
# Vamos explorar o dataset Titanic usando a biblioteca Pandas. Este dataset é frequentemente usado para introdução à análise de dados e machine learning.

# %%
# URL do dataset Titanic
url = 'https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv'

# Carregar o dataset Titanic
df = pd.read_csv(url)

# Mostra as primeiras 5 linhas do DataFrame
display(df.head())
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
# Mostra as últimas 5 linhas do DataFrame
display(df.tail())
# Out:
#      Survived  Pclass                            Name     Sex   Age  \
# 882         0       2            Rev. Juozas Montvila    male  27.0
# 883         1       1     Miss. Margaret Edith Graham  female  19.0
# 884         0       3  Miss. Catherine Helen Johnston  female   7.0
# 885         1       1            Mr. Karl Howell Behr    male  26.0
# 886         0       3              Mr. Patrick Dooley    male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard   Fare
# 882                        0                        0  13.00
# 883                        0                        0  30.00
# 884                        1                        2  23.45
# 885                        0                        0  30.00
# 886                        0                        0   7.75

# %%
# Retorna as dimensões do DataFrame (linhas, colunas)
print(df.shape)
# Out:
# (887, 8)

# %%
# Mostra o tipo de dados de cada coluna
print(df.dtypes)
# Out:
# Survived                     int64
# Pclass                       int64
# Name                        object
# Sex                         object
# Age                        float64
# Siblings/Spouses Aboard      int64
# Parents/Children Aboard      int64
# Fare                       float64
# dtype: object

# %%
# Fornece um resumo conciso do DataFrame
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB
# None

# %%
# Sumário estatístico para colunas numéricas
print(df.describe())
# Out:
#          Survived      Pclass         Age  Siblings/Spouses Aboard  \
# count  887.000000  887.000000  887.000000               887.000000
# mean     0.385569    2.305524   29.471443                 0.525366
# std      0.487004    0.836662   14.121908                 1.104669
# min      0.000000    1.000000    0.420000                 0.000000
# 25%      0.000000    2.000000   20.250000                 0.000000
# 50%      0.000000    3.000000   28.000000                 0.000000
# 75%      1.000000    3.000000   38.000000                 1.000000
# max      1.000000    3.000000   80.000000                 8.000000
#
#        Parents/Children Aboard       Fare
# count               887.000000  887.00000
# mean                  0.383315   32.30542
# std                   0.807466   49.78204
# min                   0.000000    0.00000
# 25%                   0.000000    7.92500
# 50%                   0.000000   14.45420
# 75%                   0.000000   31.13750
# ...

# %%
# Conta quantos valores NaN existem em cada coluna
print(df.isnull().sum())
# Out:
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                        0
# Siblings/Spouses Aboard    0
# Parents/Children Aboard    0
# Fare                       0
# dtype: int64

# %%
# Mostra a contagem de valores únicos na coluna 'Age'
print(df['Age'].value_counts())
# Out:
# Age
# 22.00    39
# 28.00    37
# 18.00    36
# 21.00    34
# 24.00    34
#          ..
# 0.92      1
# 23.50     1
# 36.50     1
# 55.50     1
# 74.00     1
# Name: count, Length: 89, dtype: int64

# %%
# Seleciona linhas onde a coluna 'age' é maior que 30
display(df[df['Age'] > 30])
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4           0       3                            Mr. William Henry Allen
# 6           0       1                             Mr. Timothy J McCarthy
# 11          1       1                            Miss. Elizabeth Bonnell
# ..        ...     ...                                                ...
# 869         0       3                         Mr. Victor Vander Cruyssen
# 875         1       1       Mrs. Thomas Jr (Lily Alexenia Wilson) Potter
# 877         0       3                                  Mr. Johann Markun
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 886         0       3                                 Mr. Patrick Dooley
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %% [markdown]
# ### 1.2.3 Indexação, filtragem e subconjuntos de dados

# %% [markdown]
# Neste tópico, vamos explorar técnicas eficazes para indexação, filtragem e criação de subconjuntos de dados usando Pandas. Essas operações são cruciais para a manipulação e análise de dados em qualquer projeto de ciência de dados.

# %% [markdown]
# #### - Seleção de Colunas

# %%
# Selecionar uma única coluna
display(df['Name'])
# Out:
# 0                                 Mr. Owen Harris Braund
# 1      Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2                                  Miss. Laina Heikkinen
# 3            Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4                                Mr. William Henry Allen
#                              ...
# 882                                 Rev. Juozas Montvila
# 883                          Miss. Margaret Edith Graham
# 884                       Miss. Catherine Helen Johnston
# 885                                 Mr. Karl Howell Behr
# 886                                   Mr. Patrick Dooley
# Name: Name, Length: 887, dtype: object

# %%
# Selecionar múltiplas colunas
display(df[['Name', 'Sex', 'Age']])
# Out:
#                                                   Name     Sex   Age
# 0                               Mr. Owen Harris Braund    male  22.0
# 1    Mrs. John Bradley (Florence Briggs Thayer) Cum...  female  38.0
# 2                                Miss. Laina Heikkinen  female  26.0
# 3          Mrs. Jacques Heath (Lily May Peel) Futrelle  female  35.0
# 4                              Mr. William Henry Allen    male  35.0
# ..                                                 ...     ...   ...
# 882                               Rev. Juozas Montvila    male  27.0
# 883                        Miss. Margaret Edith Graham  female  19.0
# 884                     Miss. Catherine Helen Johnston  female   7.0
# 885                               Mr. Karl Howell Behr    male  26.0
# 886                                 Mr. Patrick Dooley    male  32.0
#
# [887 rows x 3 columns]

# %% [markdown]
# #### - Seleção de Linhas por Índices

# %%
# Selecionar linhas pelos índices numéricos
display(df.iloc[5:10])  # Seleciona linhas de índice 5 a 9
# Out:
#    Survived  Pclass                                              Name     Sex  \
# 5         0       3                                   Mr. James Moran    male
# 6         0       1                            Mr. Timothy J McCarthy    male
# 7         0       3                     Master. Gosta Leonard Palsson    male
# 8         1       3  Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  female
# 9         1       2                Mrs. Nicholas (Adele Achem) Nasser  female
#
#     Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 5  27.0                        0                        0   8.4583
# 6  54.0                        0                        0  51.8625
# 7   2.0                        3                        1  21.0750
# 8  27.0                        0                        2  11.1333
# 9  14.0                        1                        0  30.0708

# %%
# Selecionar uma linha específica
display(df.iloc[10])
# Out:
# Survived                                                1
# Pclass                                                  3
# Name                       Miss. Marguerite Rut Sandstrom
# Sex                                                female
# Age                                                   4.0
# Siblings/Spouses Aboard                                 1
# Parents/Children Aboard                                 1
# Fare                                                 16.7
# Name: 10, dtype: object

# %% [markdown]
# #### - Seleção Baseada em Condições

# %%
# Selecionar linhas onde a coluna 'sex' é 'female'
display(df[df['Sex'] == 'female'])
# Out:
#      Survived  Pclass                                               Name  \
# 1           1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2           1       3                              Miss. Laina Heikkinen
# 3           1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 8           1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9           1       2                 Mrs. Nicholas (Adele Achem) Nasser
# ..        ...     ...                                                ...
# 876         1       2        Mrs. William (Imanita Parrish Hall) Shelley
# 878         0       3                        Miss. Gerda Ulrika Dahlberg
# 881         0       3                Mrs. William (Margaret Norton) Rice
# 883         1       1                        Miss. Margaret Edith Graham
# 884         0       3                     Miss. Catherine Helen Johnston
#
#         Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# ...

# %%
# Selecionar linhas com múltiplas condições
display(df[(df['Sex'] == 'male') & (df['Age'] >= 18)])
# Out:
#      Survived  Pclass                           Name   Sex   Age  \
# 0           0       3         Mr. Owen Harris Braund  male  22.0
# 4           0       3        Mr. William Henry Allen  male  35.0
# 5           0       3                Mr. James Moran  male  27.0
# 6           0       1         Mr. Timothy J McCarthy  male  54.0
# 12          0       3  Mr. William Henry Saundercock  male  20.0
# ..        ...     ...                            ...   ...   ...
# 879         0       2   Mr. Frederick James Banfield  male  28.0
# 880         0       3          Mr. Henry Jr Sutehall  male  25.0
# 882         0       2           Rev. Juozas Montvila  male  27.0
# 885         1       1           Mr. Karl Howell Behr  male  26.0
# 886         0       3             Mr. Patrick Dooley  male  32.0
#
#      Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0                          1                        0   7.2500
# ...

# %% [markdown]
# #### - Uso de .loc para Seleções Mais Complexas

# %%
# Selecionar linhas e colunas por rótulos
display(df.loc[5:10, ['Name', 'Age']])
# Out:
#                                                 Name   Age
# 5                                    Mr. James Moran  27.0
# 6                             Mr. Timothy J McCarthy  54.0
# 7                      Master. Gosta Leonard Palsson   2.0
# 8   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson  27.0
# 9                 Mrs. Nicholas (Adele Achem) Nasser  14.0
# 10                    Miss. Marguerite Rut Sandstrom   4.0

# %%
# Selecionar linhas com uma condição e colunas específicas
display(df.loc[df['Age'] < 18, ['Name', 'Sex', 'Age']])
# Out:
#                                     Name     Sex   Age
# 7          Master. Gosta Leonard Palsson    male   2.0
# 9     Mrs. Nicholas (Adele Achem) Nasser  female  14.0
# 10        Miss. Marguerite Rut Sandstrom  female   4.0
# 14   Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# 16                   Master. Eugene Rice    male   2.0
# ..                                   ...     ...   ...
# 849             Miss. Mary Conover Lines  female  16.0
# 859             Miss. Dorothy Edith Sage  female  14.0
# 865       Master. Harold Theodor Johnson    male   4.0
# 871             Miss. Adele Kiamie Najib  female  15.0
# 884       Miss. Catherine Helen Johnston  female   7.0
#
# [130 rows x 3 columns]

# %% [markdown]
# #### - Criação de Subconjuntos de Dados

# %%
# Criar um novo DataFrame apenas com passageiros adultos
adults = df[df['Age'] >= 18]
display(adults.head())
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %%
# Criar um DataFrame de crianças e adolescentes
children_and_teenagers = df[df['Age'] < 18]
display(children_and_teenagers.head())
# Out:
#     Survived  Pclass                                 Name     Sex   Age  \
# 7          0       3        Master. Gosta Leonard Palsson    male   2.0
# 9          1       2   Mrs. Nicholas (Adele Achem) Nasser  female  14.0
# 10         1       3       Miss. Marguerite Rut Sandstrom  female   4.0
# 14         0       3  Miss. Hulda Amanda Adolfina Vestrom  female  14.0
# 16         0       3                  Master. Eugene Rice    male   2.0
#
#     Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 7                         3                        1  21.0750
# 9                         1                        0  30.0708
# 10                        1                        1  16.7000
# 14                        0                        0   7.8542
# 16                        4                        1  29.1250

# %% [markdown]
# ## Tópico 1.3: Limpeza e Preparação de Dado

# %% [markdown]
# ### 1.3.1 Verificação de dados faltantes

# %% [markdown]
# A limpeza e preparação de dados são etapas cruciais em qualquer projeto de análise de dados. Dados faltantes podem distorcer as análises e afetar os resultados, por isso é importante aprender a tratá-los adequadamente.

# %% [markdown]
# #### - Leitura do dado

# %% [markdown]
# Para este tópico, vamos usar o dataset "Pima Indians Diabetes Database" disponível no UCI Machine Learning Repository. Este dataset é conhecido por ter várias entradas com valores faltantes.
# O dataset Pima Indians Diabetes é frequentemente usado em problemas de classificação para prever se uma paciente tem diabetes com base em várias medições diagnósticas. Aqui estão as descrições das colunas:
#
# - **Pregnancies**: Número de vezes grávida.
# - **Glucose**: Concentração de glicose plasmática a 2 horas em um teste oral de tolerância à glicose.
# - **BloodPressure**: Pressão arterial diastólica (mm Hg).
# - **SkinThickness**: Espessura da dobra cutânea do tríceps (mm).
# - **Insulin**: Insulina sérica de 2 horas (mu U/ml).
# - **BMI**: Índice de massa corporal (peso em kg/(altura em m)^2).
# - **DiabetesPedigreeFunction**: Uma função que representa o quão forte o diabetes é hereditário.
# - **Age**: Idade (anos).
# - **Outcome**: Variável de classe (0 ou 1) 1 indica que a paciente tem diabetes.

# %%
import pandas as pd

# URL do dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# Nomes das colunas conforme a descrição do dataset
column_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Carregar o dataset
df = pd.read_csv(url, names=column_names)

# Mostrar as primeiras linhas do DataFrame
display(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# #### - Identificar Dados Faltantes

# %% [markdown]
# No dataset Pima, os valores faltantes são codificados como zeros em algumas colunas onde zero não faz sentido como um valor válido (por exemplo, Glucose, Blood Pressure).

# %%
# Carregamento dos dados, assumindo que a substituição de zeros por NaNs já foi feita
# Seu código de carregamento aqui...

# Calculando o número total de entradas nulas em cada coluna
null_counts = df.isna().sum()

# Imprimir a contagem de não-nulos por coluna
print("Non-null counts in each column:\n", null_counts)
# Out:
# Non-null counts in each column:
#  Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Importando a biblioteca pandas para manipulação de dados
import pandas as pd

# Selecionando colunas específicas do DataFrame
colunas_selecionadas = df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']]

# Aplicando a função eq(0) para encontrar onde os valores são iguais a zero
valores_zero = colunas_selecionadas.eq(0)

# Somando os valores True retornados por eq(0) para contar quantos zeros cada coluna contém
contagem_zeros = valores_zero.sum()

# Imprimindo o resultado da contagem de zeros
display(contagem_zeros)
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %% [markdown]
# ### 1.3.2 Imputação/Preenchimento de dados

# %% [markdown]
# Existem várias estratégias para tratar dados faltantes. Duas abordagens comuns são a imputação e a exclusão de registros.

# %% [markdown]
# ##### Imputação

# %% [markdown]
# Imputar significa substituir os dados faltantes por um valor estimado. Uma prática comum é substituir os valores faltantes pela média ou mediana da coluna.

# %%
# Olhando os valores antes da imputação. Preste atenção na coluna Insulin
display(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
from sklearn.impute import SimpleImputer
import numpy as np

# Copiar dataframe
df_imputed = df.copy()

# Criar um imputer que substitui o valor zero pela média da coluna
imputer = SimpleImputer(missing_values=0, strategy='mean')

# Colunas que precisam de imputação
columns_to_impute = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Aplicar o imputer ao dataset
df_imputed[columns_to_impute] = imputer.fit_transform(df[columns_to_impute])

# Verificar novamente a presença de valores zero
display(df_imputed[columns_to_impute].eq(0).sum())
display(df_imputed.head())
# Out:
# Glucose          0
# BloodPressure    0
# SkinThickness    0
# Insulin          0
# BMI              0
# dtype: int64
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0            6    148.0           72.0       35.00000  155.548223  33.6
# 1            1     85.0           66.0       29.00000  155.548223  26.6
# 2            8    183.0           64.0       29.15342  155.548223  23.3
# 3            1     89.0           66.0       23.00000   94.000000  28.1
# 4            0    137.0           40.0       35.00000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ###### Imputação por Mediana

# %% [markdown]
# A imputação por mediana substitui os valores faltantes pela mediana da coluna, que é menos sensível a outliers em comparação com a média.

# %%
df_imputed = df.copy()

# %%
imputer_median = SimpleImputer(missing_values=0, strategy='median')
df_imputed['Glucose_median'] = imputer_median.fit_transform(df[['Glucose']])

# %% [markdown]
# ###### Imputação por Moda

# %% [markdown]
# A moda, ou o valor mais frequente, é útil em dados categóricos ou numéricos onde uma categoria ou número ocorre com maior frequência.

# %%
imputer_mode = SimpleImputer(missing_values=0, strategy='most_frequent')
df_imputed['Glucose_mode'] = imputer_mode.fit_transform(df[['Glucose']])

# %% [markdown]
# ###### Imputação KNN

# %% [markdown]
# O KNN imputa valores baseando-se nas k observações mais próximas no espaço de recurso, o que pode ser mais representativo em contextos onde as relações de similaridade são importantes.

# %%
from sklearn.impute import SimpleImputer, KNNImputer

imputer_knn = KNNImputer(missing_values=0, n_neighbors=10)
df_imputed['Glucose_knn'] = imputer_knn.fit_transform(df[['Glucose']])

# %% [markdown]
# ###### Imputação por Regressão

# %% [markdown]
# A imputação por regressão usa um modelo preditivo para estimar valores faltantes com base em outras variáveis. Aqui, usamos 'Age' como variável preditora para simplificar.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# Criar uma nova coluna 'Glucose_Regression' que é uma cópia de 'Glucose'
df_imputed['Glucose_Regression'] = df['Glucose']

# Substituir zeros por NaN para facilitar a imputação
df_imputed['Glucose_Regression'].replace(0, np.nan, inplace=True)

# Selecionar 'Age' como variável preditora para 'Glucose'
X = df_imputed[['Age']]  # Apenas a coluna 'Age' será usada como preditora
y = df_imputed['Glucose_Regression'].dropna()  # Remover NaN para o ajuste do modelo

# Dividir os dados em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(X.loc[y.index], y, test_size=0.2, random_state=42)

# Criar e treinar o modelo de regressão linear
model = LinearRegression()
model.fit(X_train, y_train)

# Prever 'Glucose' para os dados onde originalmente era NaN
predicted_glucose = model.predict(X[df_imputed['Glucose_Regression'].isna()])

# Imputar os valores preditos na nova coluna 'Glucose_Regression'
df_imputed.loc[df_imputed['Glucose_Regression'].isna(), 'Glucose_Regression'] = predicted_glucose

# %%
import pandas as pd

# Agora vamos filtrar e exibir as linhas onde 'Glucose' é NaN (originalmente zeros)
filtered_df = df_imputed[df_imputed['Glucose'].isna()]

# Para exibir as linhas onde 'Glucose' é zero sem ter substituído por NaN
filtered_df_zero = df_imputed[df_imputed['Glucose'] == 0]

# Usando display para mostrar as primeiras 50 linhas onde 'Glucose' é zero
display(filtered_df_zero.head(50))
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 75             1        0             48             20        0  24.7
# 182            1        0             74             20       23  27.7
# 342            1        0             68             35        0  32.0
# 349            5        0             80             32        0  41.0
# 502            6        0             68             41        0  39.0
#
#      DiabetesPedigreeFunction  Age  Outcome  Glucose_median  Glucose_mode  \
# 75                      0.140   22        0           117.0            99
# 182                     0.299   21        0           117.0            99
# 342                     0.389   22        0           117.0            99
# 349                     0.346   37        1           117.0            99
# 502                     0.727   41        1           117.0            99
#
#      Glucose_knn  Glucose_Regression
# 75    121.686763          113.337686
# ...

# %% [markdown]
# ### 1.3.3 Limpeza de dados por exclusão

# %% [markdown]
# Outra abordagem é simplesmente excluir dados com valores faltantes, o que pode ser viável se a quantidade de dados perdidos não for significativa.

# %%
import pandas as pd

# URL do dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

# Nomes das colunas conforme a descrição do dataset
column_names = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

# Carregar o dataset
df = pd.read_csv(url, names=column_names)

# Mostrar as primeiras linhas do DataFrame
display(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# Importando a biblioteca pandas para manipulação de dados
import pandas as pd

# Selecionando colunas específicas do DataFrame
colunas_selecionadas = df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction']]

# Aplicando a função eq(0) para encontrar onde os valores são iguais a zero
valores_zero = colunas_selecionadas.eq(0)

# Somando os valores True retornados por eq(0) para contar quantos zeros cada coluna contém
contagem_zeros = valores_zero.sum()

# Imprimindo o resultado da contagem de zeros
display(contagem_zeros)
# Out:
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# dtype: int64

# %%
# Remover linhas onde qualquer coluna tenha zero (dados faltantes não tratados anteriormente)
df_cleaned = df[(df != 0).all(axis=1)]

# Mostrar as dimensões do DataFrame antes a exclusão
print(f'Dimensões do DataFrame antes da exclusão: {df.shape}')
# Mostrar as dimensões do DataFrame após a exclusão
print(f'Dimensões do DataFrame após a exclusão: {df_cleaned.shape}')
display(df_cleaned.head())
# Out:
# Dimensões do DataFrame antes da exclusão: (768, 9)
# Dimensões do DataFrame após a exclusão: (111, 9)
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 6             3       78             50             32       88  31.0
# 8             2      197             70             45      543  30.5
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 19            1      115             70             30       96  34.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 6                      0.248   26        1
# 8                      0.158   53        1
# 13                     0.398   59        1
# 14                     0.587   51        1
# 19                     0.529   32        1

# %% [markdown]
# 1. Excluir Linhas com Qualquer Dado Faltante
#     - Exclui qualquer linha que contenha pelo menos um valor faltante.
# 2. Excluir Linhas Onde Todos os Dados Estão Faltando
#     - Embora não comum neste dataset, o método é útil para outros casos.
# 3. Excluir Colunas com Alta Proporção de Dados Faltantes
#     - Suponha que queremos remover qualquer coluna com mais de 50% de valores faltantes.

# %%
# Excluir Linhas com Qualquer Dado Faltante
df_drop_any = df.dropna()
# Excluir Linhas Onde Todos os Dados Estão Faltando
df_drop_all = df.dropna(how='all')
# Excluir Colunas com Alta Proporção de Dados Faltantes
threshold = len(df) * 0.0001  # 50% de threshold
df_drop_columns = df.dropna(axis=1, thresh=threshold)
print(threshold)

print("Original DataFrame size:", len(df))
print("Before dropping columns with >50% NaNs:", df.shape[1])
print("After dropping any rows with NaNs:", len(df_drop_any))
print("After dropping rows where all values are NaN:", len(df_drop_all))
print("After dropping columns with >50% NaNs:", df_drop_columns.shape[1])
# Out:
# 0.07680000000000001
# Original DataFrame size: 768
# Before dropping columns with >50% NaNs: 9
# After dropping any rows with NaNs: 768
# After dropping rows where all values are NaN: 768
# After dropping columns with >50% NaNs: 9

# %%
import pandas as pd

# Carregamento dos dados, assumindo que a substituição de zeros por NaNs já foi feita
# Seu código de carregamento aqui...

# Calculando o número total de entradas não-nulas em cada coluna
non_null_counts = df.notna().sum()

# Imprimir a contagem de não-nulos por coluna
print("Non-null counts in each column:\n", non_null_counts)
# Out:
# Non-null counts in each column:
#  Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64
# Number of columns before dropping: 9
# Number of columns after dropping with >10% NaNs: 9

# %%
# Lista de colunas onde zeros devem ser tratados como valores faltantes
columns_to_convert = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# Convertendo zeros para NaN nas colunas especificadas
df[columns_to_convert] = df[columns_to_convert].replace(0, pd.NA)

# Agora vamos contar os valores NaN em cada uma dessas colunas
nan_counts = df[columns_to_convert].isna().sum()

# Imprimindo o resultado da contagem de NaNs
display(nan_counts)
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
# Excluir Linhas com Qualquer Dado Faltante
df_drop_any = df.dropna()
# Excluir Linhas Onde Todos os Dados Estão Faltando
df_drop_all = df.dropna(how='all')
# Excluir Colunas com Alta Proporção de Dados Faltantes
threshold = len(df) * 0.6  # 50% de threshold
df_drop_columns = df.dropna(axis=1, thresh=threshold)
print(threshold)

print("Original DataFrame size:", len(df))
print("Before dropping columns with >50% NaNs:", df.shape[1])
print("After dropping any rows with NaNs:", len(df_drop_any))
print("After dropping rows where all values are NaN:", len(df_drop_all))
print("After dropping columns with >50% NaNs:", df_drop_columns.shape[1])
# Out:
# 460.79999999999995
# Original DataFrame size: 768
# Before dropping columns with >50% NaNs: 9
# After dropping any rows with NaNs: 392
# After dropping rows where all values are NaN: 768
# After dropping columns with >50% NaNs: 8

# %% [markdown]
# ## Tópico 1.5: Transformação de Dados

# %% [markdown]
# ## Tópico 1.4: Operações com DataFrames

# %% [markdown]
# ### 1.4.1: Operações Estatísticas Básicas com DataFrames

# %% [markdown]
# Usaremos o dataset Pima Indians Diabetes, que inclui várias medidas médicas.
# Análise estatística é um passo fundamental da análise exploratória dos dados. Isso é importante para:
#
# - **Identifica padrões e relações:** As estatísticas e visualizações ajudam a detectar padrões e possíveis correlações entre variáveis.
# - **Detecta outliers e anomalias:** Importante para decidir se esses pontos devem ser ajustados ou removidos.
# - **Informa sobre a distribuição dos dados:** Essencial para a escolha de técnicas de modelagem e para ajustar os métodos de normalização.
# - **Melhora a qualidade do modelo de machine learning:** A compreensão profunda dos dados leva a melhores decisões na fase de modelagem e a modelos mais precisos.

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
df = pd.read_csv(url, names=columns)

# %%
# Média
# Calculando a média de algumas colunas numéricas:
mean_values = df[['Glucose', 'BloodPressure', 'BMI']].mean()
print("Médias:\n", mean_values)
# Out:
# Médias:
#  Glucose          120.894531
# BloodPressure     69.105469
# BMI               31.992578
# dtype: float64

# %%
# Mediana
# Calculando a mediana:
median_values = df[['Glucose', 'BloodPressure', 'BMI']].median()
print("Medianas:\n", median_values)
# Out:
# Medianas:
#  Glucose          117.0
# BloodPressure     72.0
# BMI               32.0
# dtype: float64

# %%
# Desvio Padrão
# Calculando o desvio padrão para avaliar a dispersão dos dados:
std_deviation = df[['Glucose', 'BloodPressure', 'BMI']].std()
print("Desvio Padrão:\n", std_deviation)
# Out:
# Desvio Padrão:
#  Glucose          31.972618
# BloodPressure    19.355807
# BMI               7.884160
# dtype: float64

# %%
# Correlação
# Calculando a correlação entre as colunas para entender as relações entre elas:
correlation_matrix = df[['Glucose', 'BloodPressure', 'BMI']].corr()
print("Matriz de Correlação:\n", correlation_matrix)
# Out:
# Matriz de Correlação:
#                  Glucose  BloodPressure       BMI
# Glucose        1.000000       0.152590  0.221071
# BloodPressure  0.152590       1.000000  0.281805
# BMI            0.221071       0.281805  1.000000

# %%
# Visualização da Correlação
# Para uma melhor visualização das correlações, podemos usar um heatmap.
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True)
plt.title('Heatmap de Correlação')
plt.show()

# %%
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
df = pd.read_csv(url, names=columns)
df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.nan)

# %% [markdown]
# - **Amplitude (Range)**:
#     - A amplitude é a diferença entre o maior e o menor valor em um conjunto de dados.
#     - Ela dá uma noção da escala total dos dados.
#     - Por exemplo, se você tem um conjunto de dados com alturas de pessoas variando de 1,50 m a 2,00 m, a amplitude é de 0,50 m (ou 50 cm).
#     - Ela é útil para ter uma ideia rápida da variação total dentro de um conjunto de dados.
#     - No entanto, a amplitude é muito sensível a outliers. Um único valor extremamente alto ou baixo pode fazer a amplitude parecer muito grande, mesmo que a maioria dos dados esteja agrupada mais proximamente.
# - **Intervalo Interquartílico (IQR)**:
#     - O IQR é uma medida de dispersão estatística e é a diferença entre o terceiro quartil (Q3) e o primeiro quartil (Q1) em um conjunto de dados
#     - Ele mostra onde a "metade do meio" dos dados está localizada e é menos sensível a outliers do que a amplitude.
#     - Cálculo do IQR: se você organizar seus dados em ordem:
#         - o primeiro quartil (Q1) é o número abaixo do qual 25% dos dados caem
#         - e o terceiro quartil (Q3) é o número abaixo do qual 75% dos dados caem. O IQR é Q3 - Q1.
#     - Importância do IQR:
#         - útil para identificar outliers
#         - valores que caem mais de 1,5 vezes o IQR acima do Q3 ou abaixo do Q1 são considerados outliers.
# - **Boxplots**:
#     - Um boxplot é uma representação gráfica da distribuição de dados que ilustra a mediana, os quartis e os outliers.
#     - Permite identificar rapidamente a centralidade, dispersão e simetria dos dados
#         - Caixa: A caixa central do boxplot mostra onde o IQR reside, com a linha no meio da caixa representando a mediana (o segundo quartil, Q2).
#         - Bigodes: Os "bigodes" se estendem para fora da caixa até o menor e o maior valor dentro de 1,5 vezes o IQR a partir dos quartis Q1 e Q3. Valores além dos bigodes são considerados outliers e geralmente são representados por pontos.
#         - Outliers: Pontos individuais que caem fora dos bigodes indicam valores que são excepcionalmente altos ou baixos em relação ao resto dos dados.

# %%
#Range (Amplitude)
#Amplitude dos dados pode dar uma ideia sobre a variação dos valores numéricos.
range_data = df[columns].max() - df[columns].min()
print("Amplitude:\n", range_data)
# Out:
# Amplitude:
#  Pregnancies                  17.000
# Glucose                     155.000
# BloodPressure                98.000
# SkinThickness                92.000
# Insulin                     832.000
# BMI                          48.900
# DiabetesPedigreeFunction      2.342
# Age                          60.000
# Outcome                       1.000
# dtype: float64

# %%
#Quartis e IQR (Intervalo Interquartílico)
#Quartis são úteis para entender a distribuição dos dados, enquanto o IQR ajuda a identificar outliers.
quartiles = df[columns].quantile([0.25, 0.5, 0.75])
iqr = quartiles.loc[0.75] - quartiles.loc[0.25]
print("Quartis:\n", quartiles)
print("IQR:\n", iqr)
# Out:
# Quartis:
#        Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0.25          1.0     99.0           64.0           22.0    76.25  27.5
# 0.50          3.0    117.0           72.0           29.0   125.00  32.3
# 0.75          6.0    141.0           80.0           36.0   190.00  36.6
#
#       DiabetesPedigreeFunction   Age  Outcome
# 0.25                   0.24375  24.0      0.0
# 0.50                   0.37250  29.0      0.0
# 0.75                   0.62625  41.0      1.0
# IQR:
#  Pregnancies                   5.0000
# Glucose                      42.0000
# BloodPressure                16.0000
# SkinThickness                14.0000
# Insulin                     113.7500
# BMI                           9.1000
# DiabetesPedigreeFunction      0.3825
# Age                          17.0000
# Outcome                       1.0000
# dtype: float64

# %%
# Boxplots para todas as features numéricas
num_plots = len(columns)
num_rows = num_plots // 3 + (num_plots % 3 > 0)  # Calcula o número de linhas necessárias

fig, ax = plt.subplots(num_rows, 3, figsize=(18, num_rows * 6))  # Ajuste o tamanho conforme necessário

# Achatar o array de axes para facilitar o mapeamento dos plots para o índice correto
ax = ax.flatten()

# Criar um boxplot para cada coluna numérica
for i, column in enumerate(columns):
    sns.boxplot(data=df, y=column, ax=ax[i])
    ax[i].set_title(f'Boxplot de {column}')

# Ocultar gráficos extras que não estão sendo usados
for j in range(i+1, num_rows * 3):
    ax[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Kurtosis e Skewness

# %% [markdown]
# Kurtosis (curtose) e skewness (assimetria) são duas medidas estatísticas que descrevem a forma da distribuição dos dados. Skewness indica a assimetria da distribuição em torno da média, enquanto kurtosis descreve a 'cauda' da distribuição.
# Existem dois tipos de caudas numa distribuição:
#
# - Cauda Esquerda: distribuição à esquerda da média.
# - Cauda Direita: distribuição à direita da média.

# %% [markdown]
# Skewness mede a assimetria da distribuição dos dados em relação à média. Uma distribuição é considerada:
#
# - **Simétrica se a skewness é próxima de zero**
# - **Positivamente enviesada (skewed right) se a skewness é maior que zero**: uma skewness positiva indica que a cauda direita da distribuição é mais longa, o que, em termos práticos, significa que há uma concentração maior de valores abaixo da média. Percebemos que o pico da distribuição está do lado esquerdo.
# - **Negativamente enviesada (skewed left) se a skewness é menor que zero**: uma skewness negativa indica que a cauda esquerda da distribuição é mais longa, o que, em termos práticos, significa que há uma concentração maior de valores acima da média. Percebemos que o pico da distribuição está do lado direito.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Cálculos
skewness = df['Glucose'].skew()
mean = df['Glucose'].mean()
median = df['Glucose'].median()
mode = df['Glucose'].mode().values[0]  # Pega a primeira moda

# Plot
sns.histplot(df['Glucose'].dropna(), kde=True)
plt.axvline(mean, color='r', linestyle='--', label=f'Média: {mean:.2f}')
plt.axvline(median, color='g', linestyle='-', label=f'Mediana: {median:.2f}')
plt.axvline(mode, color='b', linestyle='-.', label=f'Moda: {mode:.2f}')
plt.legend()
plt.title('Distribuição de Glucose com KDE')
plt.xlabel('Glucose')
plt.ylabel('Frequência')
plt.show()

print("Skewness de Glucose:", skewness)
# Out:
# Skewness de Glucose: 0.5309885349396285

# %% [markdown]
# **Entendimento sobre o KDE**
# - O gráfico exibe a distribuição dos valores de glicose com uma linha do `Kernel Density Estimate (KDE)` que ajuda a visualizar a forma da `distribuição` de probabilidade dos dados
# - A `moda` marcada no gráfico é o ponto de maior frequência dos dados, que corresponde ao valor mais comum de glicose registrado, neste caso `99`
# - As outras linhas verticais mostram a `média` e a `mediana`
# - A distribuição é ligeiramente inclinada para a `direita (assimetria positiva)`, pois a `média` é `maior` que a `mediana` e a `moda`
# - A `largura` da `coluna` no histograma representa um `intervalo de valores de glicose agrupados`, não apenas o valor exato da moda
#
# **Entendimento sobre o Histograma**
# - Em histogramas, cada coluna (ou `barra`) abrange um `conjunto de valores` contínuos para `simplificar a visualização` da distribuição dos dados
# - Neste caso, mesmo que a moda seja 99, o intervalo da coluna em que ela está incluída pode cobrir valores adicionais ao redor de 99, como de 99 a 109, indicando que todos esses valores estão agrupados na mesma categoria ou bin do histograma
# - Isso não altera o fato de que 99 é o valor mais frequente (moda), apenas mostra como os dados estão distribuídos em torno dela

# %% [markdown]
# Quando a skewness é positiva significativa, podemos considerar aplicar transformações como logarítmica ou raiz quadrada para normalizar a distribuição antes de realizar análises que assumem normalidade dos dados, como testes estatísticos paramétricos ou algoritmos de machine learning baseados em distribuição normal

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Seleciona a característica
feature = columns[6]  # Certifique-se que 'columns' está definido corretamente

# Cálculos
skewness = df[feature].skew()
mean = df[feature].mean()
median = df[feature].median()
mode = df[feature].mode().values[0]  # Pega a primeira moda

# Plot
sns.histplot(df[feature].dropna(), kde=True)
plt.axvline(mean, color='r', linestyle='--', label=f'Média: {mean:.2f}')
plt.axvline(median, color='g', linestyle='-', label=f'Mediana: {median:.2f}')
plt.axvline(mode, color='b', linestyle='-.', label=f'Moda: {mode:.2f}')
plt.legend()
plt.title(f'Distribuição de {feature} com KDE')
plt.xlabel(feature)
plt.ylabel('Frequência')
plt.show()

# Imprime a assimetria
print(f"Skewness de {feature}:", skewness)
# Out:
# Skewness de DiabetesPedigreeFunction: 1.919911066307204

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

class DataLoader:
    def __init__(self, url):
        self.url = url
        self.columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]

    def load_data(self):
        df = pd.read_csv(self.url, names=self.columns)
        #df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']] = df[['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']].replace(0, np.nan)
        df[["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age"]] = df[["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age"]].replace(0, np.nan)
        return df

class SkewnessAnalyzer:
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def calculate_skewness(self):
        return self.dataframe.skew()

    def find_extreme_skewness(self):
        skewness = self.calculate_skewness()
        return skewness.idxmax(), skewness.idxmin()

class DataTransformer:
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def apply_transformations(self, feature_positive, feature_negative):
        self.dataframe[f'{feature_positive}_log'] = np.log1p(self.dataframe[feature_positive])
        self.dataframe[f'{feature_negative}_log'] = np.log1p(self.dataframe[feature_negative])

class DataPlotter:
    @staticmethod
    def plot_distributions(dataframe, features, transformed=False):
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        for i, feature in enumerate(features):
            sns.histplot(dataframe[feature].dropna(), kde=True, ax=axes[i])
            mean = dataframe[feature].mean()
            median = dataframe[feature].median()
            mode = dataframe[feature].mode().values[0]
            skewness = dataframe[feature].skew()

            # Plot lines for mean, median, and mode
            axes[i].axvline(mean, color='r', linestyle='--', label=f'Média: {mean:.2f}')
            axes[i].axvline(median, color='g', linestyle='-', label=f'Mediana: {median:.2f}')
            axes[i].axvline(mode, color='b', linestyle='-.', label=f'Moda: {mode:.2f}')
            axes[i].legend()

            # Adding skewness annotation
            axes[i].annotate(f'Skewness: {skewness:.2f}', xy=(0.05, 0.95), xycoords='axes fraction', fontsize=12, fontweight='bold', color='navy', verticalalignment='top')

            transformation = 'Log Transform' if 'log' in feature else 'Square Transform'
            title = f'Distribuição de {feature.split("_")[0]} após {transformation}' if transformed else f'Distribuição Original de {feature}'
            axes[i].set_title(title)
        plt.show()

# Usar as classes
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
loader = DataLoader(url)
df = loader.load_data()

analyzer = SkewnessAnalyzer(df)
max_positive_skew, max_negative_skew = analyzer.find_extreme_skewness()

plotter = DataPlotter()
plotter.plot_distributions(df, [max_positive_skew, max_negative_skew])

transformer = DataTransformer(df)
transformer.apply_transformations(max_positive_skew, max_negative_skew)

plotter.plot_distributions(df, [f'{max_positive_skew}_log', f'{max_negative_skew}_log'], transformed=True)

# %% [markdown]
# A curtose é uma medida estatística que descreve a `"altura"` e a "afunilamento" da `distribuição` dos dados em relação a uma distribuição normal (Gaussiana)
# - Tipos de Curtose
#     - Curtose Leptocúrtica (Curtose > 3):
#         - Uma distribuição leptocúrtica tem uma `curtose maior` que a de uma distribuição normal. Isso significa que a `distribuição` é mais `"pontiaguda"` e possui `caudas` mais `pesadas`. Isso indica uma `maior probabilidade de` ocorrerem `outliers`.
#     - Curtose Mesocúrtica (Curtose ≈ 3):
#         - Uma distribuição mesocúrtica tem uma curtose `aproximadamente igual` a da distribuição normal. Isso significa que sua `forma é semelhante à da curva normal` em termos de "pico" e "caudas".
#     - Curtose Platicúrtica (Curtose < 3):
#         - Uma distribuição platicúrtica tem uma `curtose menor` que a de uma distribuição normal. Esta `distribuição` é mais `"achatada"` em comparação com a curva normal, indicando `caudas` mais `leves` e `menos probabilidade de` ocorrerem `valores extremos`.
#
# - Utilidade da Curtose
#     - Análise de Risco e Outliers
#         - A curtose é uma ferramenta importante para a análise de riscos em finanças e seguros, pois distribuições com caudas pesadas (leptocúrticas) são mais propensas a produzir valores extremos. Isso pode influenciar decisões sobre estratégias de hedge, alocação de ativos, e gerenciamento de riscos.
#     - Melhoria de Modelos Estatísticos
#         - Entender a curtose de uma distribuição pode ajudar na escolha e na calibragem de modelos estatísticos. Por exemplo, em regressão linear, a presença de outliers pode influenciar significativamente os parâmetros do modelo. Conhecer a curtose pode levar a modificações no modelo ou na abordagem de modelagem para lidar melhor com os dados.

# %%
kurtosis = df[columns].kurtosis()
print(f"Kurtosis de {feature}:", kurtosis)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kurtosis = df[columns].kurtosis()
#       2 print(f"Kurtosis de {feature}:", kurtosis)
#
# NameError: name 'df' is not defined

# %%
# Primeiro, vamos carregar o dataset e calcular a kurtosis para cada coluna
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar o dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
df = pd.read_csv(url, names=columns)

# Calcular a kurtosis para cada coluna
kurtosis_values = df[columns].kurtosis()

# Encontrar a feature com a kurtosis mais próxima de zero
feature_closest_to_zero = kurtosis_values.sub(0).abs().idxmin()

# Encontrar a feature com a maior kurtosis em valor absoluto
feature_highest_kurtosis = kurtosis_values.abs().idxmax()

# Agora vamos gerar os gráficos de distribuição para as duas features
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot para a feature com a kurtosis mais próxima de zero
sns.histplot(df[feature_closest_to_zero].dropna(), kde=True, ax=axes[0])
axes[0].set_title(f'Distribuição de {feature_closest_to_zero} com KDE')
axes[0].set_xlabel(feature_closest_to_zero)
axes[0].set_ylabel('Densidade')

# Plot para a feature com a maior kurtosis em valor absoluto
sns.histplot(df[feature_highest_kurtosis].dropna(), kde=True, ax=axes[1])
axes[1].set_title(f'Distribuição de {feature_highest_kurtosis} com KDE')
axes[1].set_xlabel(feature_highest_kurtosis)
axes[1].set_ylabel('Densidade')

plt.tight_layout()
plt.show()

# Exibir valores de kurtosis
print(f"Kurtosis de {feature_closest_to_zero}: {kurtosis_values[feature_closest_to_zero]}")
print(f"Kurtosis de {feature_highest_kurtosis}: {kurtosis_values[feature_highest_kurtosis]}")


# Agora vamos gerar os boxplots para as duas features
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Boxplot para a feature com a kurtosis mais próxima de zero
sns.boxplot(x=df[feature_closest_to_zero], ax=axes[0])
axes[0].set_title(f'Boxplot de {feature_closest_to_zero}')

# Boxplot para a feature com a maior kurtosis em valor absoluto
sns.boxplot(x=df[feature_highest_kurtosis], ax=axes[1])
axes[1].set_title(f'Boxplot de {feature_highest_kurtosis}')

plt.tight_layout()
plt.show()
# Out:
# Kurtosis de Pregnancies: 0.15921977754746486
# Kurtosis de Insulin: 7.2142595543487715

# %% [markdown]
# ### Método para ajustar a assimetria: Yeo-Johnson

# %% [markdown]
# O `Yeo-Johnson` é uma técnica de transformação de dados usada para `estabilizar` a `variância` e `tornar a distribuição dos dados mais normal` (gaussiana). Esse método é uma extensão do método Box-Cox, que originalmente só podia ser aplicado a dados estritamente positivos. O método Yeo-Johnson, no entanto, `pode ser aplicado a dados com valores zero ou negativos`, o que o torna mais `flexível` e `útil` em uma `variedade maior de situações`.
#
# **Como funciona o método Yeo-Johnson?**
# O método Yeo-Johnson realiza transformações dos dados dependendo do valor dos mesmos, com o objetivo de reduzir problemas de `assimetria` (skewness). A transformação é definida da seguinte maneira, onde $y$ é o valor original e $λ$ é o parâmetro de transformação a ser estimado:
#
# - Para valores de $y$ maiores ou iguais a zero:
#
#   $y(\lambda) =
#   \begin{cases}
#   \frac{(y + 1)^\lambda - 1}{\lambda} & \text{se } \lambda \neq 0 \\
#   \log(y + 1) & \text{se } \lambda = 0
#   \end{cases}
#   $
#
# - Para valores de $y$ menores que zero:
#
#   $
#   y(\lambda) =
#   \begin{cases}
#   -\frac{(-y + 1)^{2 - \lambda} - 1}{2 - \lambda} & \text{se } 2 - \lambda \neq 0 \\
#   -\log(-y + 1) & \text{se } 2 - \lambda = 0
#   \end{cases}
#   $
#
# **Aplicações e Vantagens**
# - **Reduzir a Assimetria:** Ideal para dados que têm uma distribuição assimétrica, ajudando a linearizar relações, estabilizar a variância e normalizar a distribuição.
# - **Modelos de Machine Learning:** Muitos modelos (especialmente aqueles baseados em regressão) assumem que os dados seguem uma distribuição normal. Transformar os dados para se aproximarem dessa suposição pode melhorar significativamente o desempenho do modelo.
# - **Flexibilidade:** Funciona com dados zero e negativos, ao contrário do método Box-Cox.
# ​

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import PowerTransformer
from sklearn.impute import SimpleImputer

class DataLoader:
    def __init__(self, url):
        self.url = url
        self.columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]

    def load_data(self):
        df = pd.read_csv(self.url, names=self.columns)
        df[["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]] = df[["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]].replace(0, np.nan)
        return df

class StatsAnalyzer:
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def calculate_stats(self):
        skewness = self.dataframe.skew()
        kurtosis = self.dataframe.kurt()
        return skewness, kurtosis

class DataTransformer:
    def __init__(self, dataframe):
        self.dataframe = dataframe

    def apply_yeo_johnson_transformation(self):
        transformer = PowerTransformer(method='yeo-johnson')
        self.dataframe = self.dataframe.dropna()  # Ensure no NaNs which could cause errors
        transformed_data = transformer.fit_transform(self.dataframe)
        return pd.DataFrame(transformed_data, columns=self.dataframe.columns)

class DataPlotter:
    @staticmethod
    def plot_comparison(original_df, transformed_df, original_stats, transformed_stats):
        fig, axes = plt.subplots(nrows=len(original_df.columns), ncols=2, figsize=(12, len(original_df.columns)*3))
        for i, col in enumerate(original_df.columns):
            sns.histplot(original_df[col], kde=True, ax=axes[i, 0], color="blue", stat="density")
            axes[i, 0].set_title(f'Original Distribution of {col}\nSkewness: {original_stats[0][col]:.2f} | Kurtosis: {original_stats[1][col]:.2f}')
            sns.histplot(transformed_df[col], kde=True, ax=axes[i, 1], color="green", stat="density")
            axes[i, 1].set_title(f'Transformed Distribution of {col}\nSkewness: {transformed_stats[0][col]:.2f} | Kurtosis: {transformed_stats[1][col]:.2f}')
        plt.tight_layout()
        plt.show()

    @staticmethod
    def plot_boxplots(original_df, transformed_df):
        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
        sns.boxplot(data=original_df, ax=axes[0], palette="Blues")
        axes[0].set_title('Original Data Boxplots')
        axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=90)

        sns.boxplot(data=transformed_df, ax=axes[1], palette="Greens")
        axes[1].set_title('Transformed Data Boxplots')
        axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=90)

        plt.tight_layout()
        plt.show()

# Usar as classes
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
loader = DataLoader(url)
df = loader.load_data()

analyzer = StatsAnalyzer(df.drop(columns=['Outcome']))  # Exclude non-numeric 'Outcome' column
original_skewness, original_kurtosis = analyzer.calculate_stats()

transformer = DataTransformer(df.drop(columns=['Outcome']))
df_transformed = transformer.apply_yeo_johnson_transformation()

transformed_analyzer = StatsAnalyzer(df_transformed)
transformed_skewness, transformed_kurtosis = transformed_analyzer.calculate_stats()

plotter = DataPlotter()
plotter.plot_comparison(df.drop(columns=['Outcome']), df_transformed, (original_skewness, original_kurtosis), (transformed_skewness, transformed_kurtosis))
plotter.plot_boxplots(df.drop(columns=['Outcome']), df_transformed)

# %% [markdown]
# ### Método de Ajuste da Curtose: Transformação de Tukey

# %% [markdown]
# Um método eficaz para ajustar a curtose é a **Transformação de Tukey** (também conhecida como "Ladder of Powers"). A transformação de Tukey pode ajudar a normalizar os dados, ajustando tanto a assimetria quanto a curtose. A transformação é definida como:
#
# $
# y(\lambda) =
# \begin{cases}
# \frac{y^\lambda - 1}{\lambda} & \text{se } \lambda \neq 0 \\
# \log(y) & \text{se } \lambda = 0
# \end{cases}
# $
#
# Onde:
# - $y$ é o valor original dos dados.
# - $\lambda$ é o parâmetro de transformação, que determina a natureza da transformação a ser aplicada.
#
# A "Ladder of Powers" é uma abordagem que permite diferentes transformações dependendo do valor escolhido para o parâmetro $\lambda$. Cada valor de $\lambda$ representa uma transformação específica que pode ser aplicada aos dados:
#
# - $\lambda = -1$: **Transformação recíproca**.
# - $\lambda = -0.5$: **Transformação recíproca da raiz quadrada**.
# - $\lambda = 0$: **Transformação logarítmica**.
# - $\lambda = 0.5$: **Transformação de raiz quadrada**.
# - $\lambda = 1$: **Nenhuma transformação** (os dados permanecem os mesmos).
# - $\lambda = 2$: **Transformação quadrada**.
#
# **Diferença entre Atribuição Manual e Automática de $\lambda$**
#
#
# Quando se utiliza a Transformação de Tukey:
#
# - **Atribuição Manual de $\lambda$**: A escolha de $\lambda$ é feita baseada em conhecimento prévio ou experimentação direta. Esta abordagem permite controle total sobre o tipo de transformação aplicada e é útil quando já se tem uma noção de qual transformação poderia beneficiar mais os dados conforme sua distribuição original.
#
# - **Atribuição Automática de $\lambda$**: Esta abordagem utiliza métodos de otimização para encontrar o valor de $\lambda$ que melhor atende a um critério específico, geralmente a minimização da assimetria ou da curtose dos dados transformados. O valor de $\lambda$ é determinado automaticamente por algoritmos, o que pode ser mais eficiente em casos onde não há uma clara expectativa sobre qual valor de $\lambda$ seria o mais adequado.
#
# A escolha entre a atribuição manual e automática de $\lambda$ depende do objetivo da análise, da familiaridade com os dados, e das características específicas dos dados que estão sendo analisados. A atribuição automática é particularmente útil para maximizar a eficiência estatística sem a necessidade de intervenção manual extensiva.
#
# **Importância Prática de Ajustar a Curtose para Zero**
#
# Ajustar a curtose para valores próximos de zero é crucial em diversas áreas analíticas e de pesquisa, onde a suposição de normalidade subjacente impacta diretamente a validade e a eficácia das técnicas estatísticas utilizadas. Aqui estão algumas áreas específicas onde isso é particularmente relevante:
#
# - **Testes Estatísticos Paramétricos**: Muitos testes estatísticos, como o teste t de Student para comparação de médias e o teste ANOVA para análise de variância, assumem que os dados seguem uma distribuição normal. Uma curtose distante de zero pode indicar que a distribuição tem caudas muito pesadas ou leves, o que pode levar a conclusões errôneas sobre a significância estatística devido a uma maior frequência de valores extremos do que o esperado em uma distribuição normal.
#
# - **Modelagem Preditiva**: Em modelagem preditiva, especialmente em técnicas que assumem normalidade dos resíduos (como regressão linear), ter dados com uma distribuição próxima da normalidade (curtose ~0) é fundamental. Isso garante que o modelo é bem especificado e que as inferências e previsões são mais precisas. Dados com alta curtose podem resultar em modelos que são excessivamente influenciados por outliers, comprometendo a generalização do modelo.
#
# - **Controle de Qualidade**: Em contextos de controle de qualidade, especialmente na indústria de manufatura, assumir a normalidade dos dados pode ajudar a definir limites de controle mais eficazes. Uma curtose elevada pode significar que o processo está sujeito a falhas extremas com mais frequência do que o previsto, enquanto uma curtose reduzida pode sugerir um controle excessivo que não permite variação natural no processo de manufatura.
#
# - **Análise de Riscos**: Em finanças e seguros, a análise de riscos muitas vezes depende da normalidade dos dados para modelar eventos extremos e riscos potenciais. Uma curtose ajustada para zero ajuda a modelar riscos de maneira mais eficiente, evitando superestimação ou subestimação de eventos raros.
#
# - **Análise Exploratória**: Facilita a identificação de tendências nos dados.

# %% [markdown]
# **Estimação de $\lambda$**
#
# A escolha de $\lambda$ que minimiza a curtose ou assimetria é feita através de otimização. Abaixo, um exemplo de código para estimar $\lambda$ utilizando Python:

# %%
import numpy as np
import pandas as pd
from scipy.optimize import minimize_scalar

# Simulação de dados
data = np.random.exponential(size=1000) + 1  # Adiciona 1 para evitar o log de zero

# Função para calcular a curtose
def kurtosis_function(lmbda):
    if lmbda == 0:
        transformed_data = np.log(data)
    else:
        transformed_data = (np.power(data, lmbda) - 1) / lmbda
    return pd.Series(transformed_data).kurtosis()

# Estimação de lambda que minimiza a curtose
result = minimize_scalar(kurtosis_function, bounds=(-2, 3), method='bounded')

print("Valor ótimo de lambda para minimizar a curtose:", result.x)
# Out:
# Valor ótimo de lambda para minimizar a curtose: -1.2405373928953531

# %% [markdown]
# ### Método de Ajuste Automático usando a Transformação de Tukey

# %% [markdown]
# A atribuição automática de $λ$ na `Transformação de Tukey` pode ser direcionada tanto para `minimizar a assimetria quanto a curtose dos dados` transformados, `dependendo dos objetivos específicos` da análise estatística.
#
# **Minimização da Assimetria**
#
# Quando o `objetivo` é tornar a `distribuição mais simétrica`, o valor de $𝜆$ é ajustado para `minimizar a medida de assimetria` (skewness). Uma distribuição simétrica é frequentemente desejável em muitas técnicas estatísticas que assumem que os dados são simetricamente distribuídos em torno da média, como em muitos testes paramétricos e procedimentos de inferência.
#
# **Minimização da Curtose**
#
# Se o `foco` está em `normalizar as caudas da distribuição` e torná-las `comparáveis às de uma distribuição normal` (curtose próxima de zero), o $λ$ é escolhido para minimizar a `curtose`. Isso pode ser particularmente útil em situações onde a `presença de outliers` ou eventos extremos pode `afetar` adversamente a análise, como em modelagem de risco ou em certos tipos de `modelagem preditiva`.
#
# **Escolha entre Assimetria e Curtose**
#
# Em `algumas situações`, pode haver um compromisso entre `minimizar a assimetria e a curtose`, e a escolha pode `depender de qual característica é mais crítica` para a análise específica ou para o `desempenho do modelo`. Além disso, em `certos casos`, pode-se realizar uma `sequência de otimizações: primeiro minimizando a assimetria e, em seguida, ajustando o $λ$ para reduzir a curtose`, ou vice-versa.
#
# A implementação de uma atribuição automática eficaz geralmente envolve o uso de `algoritmos de otimização`, como o método de descida de gradiente, algoritmos genéticos, ou métodos de otimização baseados em busca em grade (grid search), que exploram sistematicamente uma gama de valores de $λ$ para encontrar o que melhor atende ao critério desejado.
#
# Aqui está um exemplo de como isso pode ser implementado para ambos os critérios usando Python:

# %%
import numpy as np
import pandas as pd
from scipy.stats import skew, kurtosis
from scipy.optimize import minimize_scalar

def optimize_lambda(data, target='skewness'):
    """
    Optimiza o lambda para minimizar a skewness ou a curtose
    utilizando a transformação de Tukey.

    Args:
    data (array-like): Os dados a serem transformados.
    target (str): 'skewness' ou 'kurtosis' para minimização.

    Returns:
    float: O valor ótimo de lambda encontrado.
    """
    # Função objetivo para minimização
    def objective(lmbda):
        if lmbda == 0:
            transformed_data = np.log(data + 1)  # log transform, shift para evitar log(0)
        else:
            transformed_data = (np.power(data + 1, lmbda) - 1) / lmbda
        
        if target == 'skewness':
            return abs(skew(transformed_data))  # minimiza o valor absoluto da skewness
        else:
            return abs(kurtosis(transformed_data) - 3)  # curtose excessiva próxima de zero

    # Resultado da otimização
    result = minimize_scalar(objective, bounds=(-2, 2), method='bounded')
    return result.x

# Exemplo de uso:
data = np.random.gamma(2, 2, 1000) - 1  # Dados para transformação
lambda_for_skewness = optimize_lambda(data, 'skewness')
lambda_for_kurtosis = optimize_lambda(data, 'kurtosis')

print("Lambda para minimizar skewness:", lambda_for_skewness)
print("Lambda para minimizar curtose:", lambda_for_kurtosis)
# Out:
# Lambda para minimizar skewness: 0.3133047250590092
# Lambda para minimizar curtose: 1.2293012882309107

# %% [markdown]
# Melhorias Implementadas:
# - Tratamento de Dados: adicionamos $+1e-2$ em todas as transformações para garantir que operações como logaritmo não resultem em erro devido a valores zero.
# - Otimização para Ambos os Casos: Agora otimizamos o $𝜆$ tanto para minimizar a assimetria quanto a curtose de maneira independente para cada coluna.
# - Melhor Apresentação dos Gráficos: Cada coluna tem três gráficos: dados originais, dados com assimetria minimizada e dados com curtose minimizada, todos com títulos e legendas claras para fácil comparação.
# - Robustez: O código agora lida de forma mais robusta com dados potencialmente problemáticos, garantindo que todas as entradas sejam válidas para as transformações aplicadas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
from scipy.optimize import minimize_scalar

# Carregar dados
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
data = pd.read_csv(url, names=columns)
data = data.drop(columns=['Outcome'])  # Remover 'Outcome' pois é categórica
data.replace(0, np.nan, inplace=True)  # Substituir zeros por NaN para processamento adequado

# Função para aplicar a Transformação de Tukey
def tukey_transform(data, lmbda):
    if lmbda == 0:
        transformed_data = np.log(data + 1e-2)  # Adiciona pequeno valor para garantir não-negatividade
    else:
        transformed_data = (np.power(data + 1e-2, lmbda) - 1) / lmbda
    return transformed_data

# Função para otimizar o lambda
def optimize_lambda(data, target='skewness'):
    data = data.dropna()  # Remover quaisquer NaNs para evitar erros na otimização
    def objective(lmbda):
        transformed_data = tukey_transform(data, lmbda)
        if target == 'skewness':
            return abs(skew(transformed_data))
        else:
            return abs(kurtosis(transformed_data))
    
    result = minimize_scalar(objective, bounds=(-2, 2), method='bounded')
    return result.x

# Aplicar transformações e plotar
fig, axes = plt.subplots(nrows=len(data.columns), ncols=3, figsize=(18, 5 * len(data.columns)))

for i, column in enumerate(data.columns):
    clean_data = data[column].dropna()  # Remover NaNs
    original_skew = skew(clean_data)
    original_kurt = kurtosis(clean_data)

    lambda_skew = optimize_lambda(clean_data, 'skewness')
    lambda_kurt = optimize_lambda(clean_data, 'kurtosis')
    
    # Original data
    sns.histplot(clean_data, kde=True, ax=axes[i, 0], color="blue")
    axes[i, 0].set_title(f'Original {column}\nSkew: {original_skew:.2f}, Kurt: {original_kurt:.2f}')

    # Minimizar assimetria
    data_skew_transformed = tukey_transform(clean_data, lambda_skew)
    transformed_skew = skew(data_skew_transformed)
    transformed_kurt_skew = kurtosis(data_skew_transformed)
    sns.histplot(data_skew_transformed, kde=True, ax=axes[i, 1], color="green")
    axes[i, 1].set_title(f'Min Skewness {column}\nλ={lambda_skew:.2f}, Skew: {transformed_skew:.2f}, Kurt: {transformed_kurt_skew:.2f}')

    # Minimizar curtose
    data_kurt_transformed = tukey_transform(clean_data, lambda_kurt)
    transformed_kurt = kurtosis(data_kurt_transformed)
    transformed_skew_kurt = skew(data_kurt_transformed)
    sns.histplot(data_kurt_transformed, kde=True, ax=axes[i, 2], color="red")
    axes[i, 2].set_title(f'Min Kurtosis {column}\nλ={lambda_kurt:.2f}, Skew: {transformed_skew_kurt:.2f}, Kurt: {transformed_kurt:.2f}')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew, kurtosis
from scipy.optimize import minimize_scalar

# Carregar dados
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
columns = ["Pregnancies", "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI", "DiabetesPedigreeFunction", "Age", "Outcome"]
data = pd.read_csv(url, names=columns)
data = data.drop(columns=['Outcome'])  # Remover 'Outcome' pois é categórica
data.replace(0, np.nan, inplace=True)  # Substituir zeros por NaN para processamento adequado

# Função para aplicar a Transformação de Tukey
def tukey_transform(data, lmbda):
    if lmbda == 0:
        transformed_data = np.log(data + 1e-2)  # Adiciona pequeno valor para garantir não-negatividade
    else:
        transformed_data = (np.power(data + 1e-2, lmbda) - 1) / lmbda
    return transformed_data

# Função para otimizar o lambda
def optimize_lambda(data, target='skewness'):
    data = data.dropna()  # Remover quaisquer NaNs para evitar erros na otimização
    def objective(lmbda):
        transformed_data = tukey_transform(data, lmbda)
        if target == 'skewness':
            return abs(skew(transformed_data))
        else:
            return abs(kurtosis(transformed_data))
    
    result = minimize_scalar(objective, bounds=(-2, 2), method='bounded')
    return result.x

# Aplicar transformações e plotar
fig, axes = plt.subplots(nrows=len(data.columns), ncols=6, figsize=(24, 10 * len(data.columns)))

for i, column in enumerate(data.columns):
    clean_data = data[column].dropna()  # Remover NaNs
    original_skew = skew(clean_data)
    original_kurt = kurtosis(clean_data)

    lambda_skew = optimize_lambda(clean_data, 'skewness')
    lambda_kurt = optimize_lambda(clean_data, 'kurtosis')
    
    # Original data - Histogram and Boxplot
    sns.histplot(clean_data, kde=True, ax=axes[i, 0], color="blue")
    axes[i, 0].set_title(f'Original {column}\nSkew: {original_skew:.2f}, Kurt: {original_kurt:.2f}')
    sns.boxplot(x=clean_data, ax=axes[i, 1], color="blue")
    axes[i, 1].set_title(f'Original {column} - Boxplot')

    # Minimizar assimetria - Histogram and Boxplot
    data_skew_transformed = tukey_transform(clean_data, lambda_skew)
    transformed_skew = skew(data_skew_transformed)
    transformed_kurt_skew = kurtosis(data_skew_transformed)
    sns.histplot(data_skew_transformed, kde=True, ax=axes[i, 2], color="green")
    axes[i, 2].set_title(f'Min Skewness {column}\nλ={lambda_skew:.2f}, Skew: {transformed_skew:.2f}, Kurt: {transformed_kurt_skew:.2f}')
    sns.boxplot(x=data_skew_transformed, ax=axes[i, 3], color="green")
    axes[i, 3].set_title(f'Min Skewness {column} - Boxplot')

    # Minimizar curtose - Histogram and Boxplot
    data_kurt_transformed = tukey_transform(clean_data, lambda_kurt)
    transformed_kurt = kurtosis(data_kurt_transformed)
    transformed_skew_kurt = skew(data_kurt_transformed)
    sns.histplot(data_kurt_transformed, kde=True, ax=axes[i, 4], color="red")
    axes[i, 4].set_title(f'Min Kurtosis {column}\nλ={lambda_kurt:.2f}, Skew: {transformed_skew_kurt:.2f}, Kurt: {transformed_kurt:.2f}')
    sns.boxplot(x=data_kurt_transformed, ax=axes[i, 5], color="red")
    axes[i, 5].set_title(f'Min Kurtosis {column} - Boxplot')

plt.tight_layout()
plt.show()
